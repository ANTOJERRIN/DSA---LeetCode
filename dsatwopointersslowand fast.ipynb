# %%
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        k=0
        for f in range(len(nums)):
            if nums[f] != val:
                nums[k]=nums[f]
                k+=1
        return k
