# %%
the thing is i have crossed from funda to condtiional statements in python:
from geeksforgeeks
# Out:
#   Cell In[1], line 1
#     the thing is i have crossed from funda to condtiional statements in python:
#         ^
# SyntaxError: invalid syntax

# %%
x=5
try:
    rem=x//10*34
    print(rem)
except:
    print("it is a foolish error")
# Out:
# 0

# %%
num=1
match num:
    case 1:
        print("hola")
    case -3:
        print("namaste")
    case _:
        print("no match")
# Out:
# hola
