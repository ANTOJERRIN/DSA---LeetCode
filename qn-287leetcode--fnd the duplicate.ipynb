# %%
# the pyhton implementation
# 1.
class Solution:
    def findDuplicate(self, nums: list[int]) -> int:
        seen=set()
        for num in nums:
            if num in seen:
                return num
            seen.add(num)    

# 2.
class Solution:
    def findDuplicate(self, nums: list[int]) -> int:
        f=nums.sort()
        for i in nums:
            if(nums[i]==nums[i-1]):
                return nums[i]

# %%
# the c++ code implementation is :
class Solution {
public:
    int findDuplicate(vector<int>& nums) {
        sort(nums.begin(),nums.end());
        int c=0,d=0;
        int n=nums.size();
        if(n<0) return 0;
        for(int i=1;i<n;i++)
        {
          if(nums[i] == nums[i-1]) {
          return nums[i]; 
          }
        }
      
        return 0;
    }
};
