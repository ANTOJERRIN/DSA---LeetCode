# %%
# this is the pyhton file
class Solution:
    def countCommas(self, n: int) -> int:
        t=0
        if n<1000:
            print(0)
        elif n>=1000:
            t=n-999    
        return t

# %%
# this is the c++ code
class Solution {
public:
    int countCommas(int n) {
        int totalcommas=0;
        if(n<1000) cout<<0;
        else if(n>=1000){
            totalcommas=n-999;

        }
        return totalcommas;
        
    }
};
